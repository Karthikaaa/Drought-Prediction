# %%
import sagemaker
from sagemaker.model import Model

# Initialize SageMaker session and specify your role
sagemaker_session = sagemaker.Session()
role = 'arn:aws:iam::637423247598:role/service-role/AmazonSageMaker-ExecutionRole-20240819T182046'  

# Docker image URI for scikit-learn
image_uri = '763104351884.dkr.ecr.us-west-2.amazonaws.com/sagemaker-scikit-learn:0.23-1-cpu-py3'

# Define the model, specifying the inference script as the entry point
model = Model(
    image_uri=image_uri,
    model_data='s3://sagemaker-studio-637423247598-ibwjh7qnlsc/model.zip',
    role=role,
    sagemaker_session=sagemaker_session,
    # entry_point='s3://sagemaker-studio-637423247598-ibwjh7qnlsc/models/inference.py'  # Custom inference script
    entry_point='inference.py'  # Custom inference script
)

# Deploy the model
predictor = model.deploy(
    initial_instance_count=1,
    instance_type='ml.m5.2xlarge',  # Instance type
    endpoint_name='random-forest-endpoint'
)

print("Model deployed successfully.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 22
#      12 model = Model(
#      13     image_uri=image_uri,
#      14     model_data='https://sagemaker-studio-637423247598-ibwjh7qnlsc.s3.eu-north-1.amazonaws.com/models/',
#    (...)
#      18     entry_point='inference.py'  # Custom inference script
#      19 )
#      21 # Deploy the model
# ---> 22 predictor = model.deploy(
#      23     initial_instance_count=1,
#      24     instance_type='ml.m5.2xlarge',  # Instance type
#      25     endpoint_name='random-forest-endpoint'
#      26 )
#      28 print("Model deployed successfully.")
#
# ...
